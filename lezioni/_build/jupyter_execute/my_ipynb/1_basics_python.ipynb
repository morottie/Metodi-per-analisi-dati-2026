# %% [markdown]
# # Basi di Python
#
# Python è oggi uno dei linguaggi di programmazione più diffusi e viene utilizzato in numerosi ambiti, dallo sviluppo software alla Data Science, dal Machine Learning al calcolo scientifico. La sua popolarità è dovuta soprattutto alla sintassi chiara, alla grande disponibilità di librerie specializzate e a una comunità di sviluppatori molto ampia.
#
# In questo corso daremo per acquisita una conoscenza di base del funzionamento e della sintassi di Python. Tuttavia, prima di affrontare le librerie e gli strumenti specifici per il calcolo numerico, in questo notebook richiameremo brevemente alcuni elementi fondamentali del linguaggio.
#
# In particolare, rivedremo la definizione e l’uso delle variabili, i principali tipi di dato, gli operatori, le strutture condizionali e iterative, le principali strutture dati e la definizione di funzioni.
#
# Questa introduzione non vuole essere un corso completo di programmazione in Python, ma un ripasso delle conoscenze necessarie per comprendere e svolgere le successive attività di laboratorio. Chi non ha sufficiente familiarità con la sintassi di base è invitato a integrare questo materiale con un tutorial completo.

# %% [markdown]
# ## Premessa
#
# In Python l’*indentazione* non ha soltanto una funzione grafica, ma fa parte della sintassi del linguaggio: viene utilizzata per identificare le istruzioni appartenenti allo stesso blocco di codice. Convenzionalmente, ogni livello di indentazione corrisponde a quattro spazi.
#
# Un’indentazione mancante o incoerente produce un errore oppure modifica il significato del programma.

# %% [markdown]
# ## (1) Tipi di dato
#
# In Python ogni valore è un oggetto caratterizzato da un tipo.
#
# Precisamente, Python è un linguaggio **a tipizzazione dinamica**: quando si crea una variabile non è necessario dichiararne esplicitamente il tipo, perchè viene determinato automaticamente in base al valore assegnato.
# NB: in Python il tipo appartiene all’oggetto, mentre una variabile è un nome che fa riferimento a quell’oggetto. Durante l’esecuzione, la stessa variabile può quindi essere associata a oggetti di tipo diverso.
#
# Per conoscere il tipo dell’oggetto associato a una variabile si utilizza la funzione `type()`, che restituisce il tipo dell’oggetto ricevuto come argomento.

# %%
x = 5          # x fa riferimento a un oggetto di tipo int
print(type(x))

x = "ciao"     # ora x fa riferimento a un oggetto di tipo str
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Per comodità didattica distingueremo i tipi di dato elementari, che rappresentano singoli valori, dalle strutture dati, utilizzate per raccogliere e organizzare più valori.

# %% [markdown]
# ### 1.1 Tipi di dato elementari
#
# I tipi di dato elementari rappresentano singoli valori. I principali tipi predefiniti di Python sono:
#
# * `int`, per i numeri interi;
# * `float`, per i numeri in virgola mobile;
# * `complex`, per i numeri complessi;
# * `bool`, per i valori logici `True` e `False`;
# * `str`, per le stringhe di caratteri;
# * `NoneType`, il cui unico valore possibile è `None`, usato per indicare l’assenza di un valore.

# %%
n = 12
x = 3.14
z = 2 + 3j
esito = True
testo = "Python"
risultato = None

print(type(n))          # <class 'int'>
print(type(x))          # <class 'float'>
print(type(z))          # <class 'complex'>
print(type(esito))      # <class 'bool'>
print(type(testo))      # <class 'str'>
print(type(risultato))  # <class 'NoneType'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %%
n = float(n)
x = int(x)
esito = int(esito)
print(n, type(n))
print(x, type(x))
print(esito, type(esito))
# Out:
# 12.0 <class 'float'>
# 3 <class 'int'>
# 1 <class 'int'>

# %% [markdown]
# > **Nota:**
# Python è **case-sensitive**: distingue cioè tra lettere maiuscole e minuscole. Pertanto, a e A sono due nomi di variabile distinti.

# %%
# Define variables a and A
a = "Hello,"
A = "World!"

print(a)
print(A)
# Out:
# Hello,
# World!

# %% [markdown]
# Il nome di una variabile:
#
# * può contenere lettere, cifre e il carattere underscore _;
# * non può iniziare con una cifra;
# * non può contenere spazi o simboli come -, +, @, %, #;
# * non può coincidere con una parola riservata di Python come if, for, while o class.

# %%
numero_studenti = 25  # valido
x2 = 4.5              # valido
_valore = 10          # valido

2x = 5                # non valido: inizia con una cifra
numero-studenti = 25  # non valido: contiene un trattino
for = 3               # non valido: "for" è una parola riservata
# Out:
#   Cell In[5], line 5
#     2x = 5                # non valido: inizia con una cifra
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# #### Le f-string per la funzione print()
#
#
# Le `f-string` (formatted string literals)  sono una modalità sintattica per costruire e formattare stringhe. Il risultato della valutazione di una f-string è un normale oggetto di tipo `str`.
#
# Sono molto utili per rendere le stampe più comprensibili: consentono infatti di inserire direttamente all’interno di una stringa il valore di variabili o il risultato di espressioni.
#
# Si definiscono anteponendo la lettera f alla stringa e racchiudendo le espressioni tra parentesi graffe `{}` (placeholder).

# %%
nome = "Anna"
eta = 21
messaggio = f"{nome} ha {eta} anni."
print(messaggio)
print(type(messaggio))  # <class 'str'>
print("\n")

x = 100//81
y = 100%81
print(f"100/81 = {100/81}")
print(f"\tLa divisione intera è: {x};")
print(f"\tL'operatore modulo (resto) è: {y}.")

x = 100/77
print(x)
print(f"\t Il valore arrotondato di x è: {x:0.4f}.")

x = 100/81
print(x)
print(f"\t Il valore arrotondato di x è: {x:0.4f}.")

# %% [markdown]
# Per maggiori informazioni sull'operatore di formattazione usato nel placeholder (cioè i `:` con le specifiche) e le opzioni di formattazione delle stringhe, fare riferimento al sito: https://www.w3schools.com/python/python_string_formatting.asp.

# %% [markdown]
# ### 1.2 Strutture dati
#
# Le strutture dati permettono di raccogliere e organizzare più valori all’interno di un unico oggetto. Tecnicamente, le strutture dati sono oggetti dotati di un tipo.
#
# Python mette a disposizione diverse strutture dati predefinite, ciascuna adatta a esigenze differenti:
#
# * le **liste** (`list`);
# * le **tuple** (`tuple`);
# * gli **intervalli** (`range`);
# * gli **insiemi** (`set`);
# * i **dizionari** (`dict`).

# %% [markdown]
# Le diverse strutture si distinguono principalmente per:
#
# * ordine degli elementi;
# * possibilità di essere modificate;
# * possibilità di contenere duplicati;
# * modalità di accesso agli elementi.
#
# | Struttura | Ordinata | Modificabile |     Duplicati | Accesso         |
# | --------- | -------: | -----------: | ------------: | --------------- |
# | `list`    |       sì |           sì |            sì | mediante indice |
# | `tuple`   |       sì |           no |            sì | mediante indice |
# | `range`   |       sì |           no |            sì | mediante indice |
# | `set`     |       no |           sì |            no | nessun indice   |
# | `dict`    |   sì$^*$ |           sì | chiavi uniche | mediante chiave |
#
# $^*$ Nei dizionari viene preservato l’ordine di inserimento degli elementi; tuttavia, gli elementi sono identificati e recuperati attraverso le loro chiavi, non attraverso una posizione numerica.

# %% [markdown]
# A differenza degli array numerici che vedremo successivamente, le strutture dati di Python possono generalmente contenere elementi di tipo diverso.

# %%
dati = [10, 3.14, "Python", True] # lista

print(dati)
print(type(dati))

# %% [markdown]
# Le strutture possono anche essere annidate, cioè contenere altre strutture dati:

# %%
dati = [
    ["Anna", 25],
    ["Luca", 28],
    ["Sara", 22]
]

print(type(dati))
print( dati[0] )
print(type(dati[0]))

# %% [markdown]
# #### Array di tipo `list`
# Una lista è una sequenza ordinata e modificabile di elementi. Si definisce racchiudendo gli elementi tra parentesi quadre [] e separandoli con una virgola.

# %%
numeri = [10, 120, 30, -40] 
nomi = ["Anna", "Maria", "Daniel", "Fatima", "Lucas", "Sara", "Mohamed", "Andrei", "Blerina"] 
lista_vuota = []

# %% [markdown]
# Gli elementi di una lista sono identificati da un indice intero, la cui numerazione inizia da zero.
# Gli indici negativi permettono di contare gli elementi a partire dalla fine: -1 indica l’ultimo elemento, -2 il penultimo e così via.

# %%
print(numeri[0]) 
print(numeri[2])  
print(numeri[-1]) 
print(nomi[2])
print(nomi[-2])

print(len(nomi)) # len restituisce il numero di elementi
print(nomi[12])  # IndexError: list index out of range

# %% [markdown]
# > **Nota:**
# Le liste sono **modificabili** (mutable): è possibile sostituire, aggiungere o eliminare elementi dopo la loro creazione.

# %%
nomi[0] = "Elena"
nomi.append("Amelia") # aggiunge un elemento in fondo 
# nomi[12] = "Amelia"
print(nomi)
print(len(nomi))

# %%
# Alcuni metodi utili:

nomi.append("Amina") 
nomi.insert(4, "Daniel") # inserisce Daniel nella posizione 4 
print(nomi)

nomi.remove("Daniel") # elimina la prima occorrenza di Daniel 
ultimo = nomi.pop() # elimina e restituisce l'ultimo elemento 
print(ultimo)
print(nomi)

# %%
print(numeri)
print(f"il massimo valore è: {max(numeri)}")
print(f"il minimo valore è: {min(numeri)}")

numeri.sort() # ordina la lista 
print(numeri)
numeri.reverse() # inverte l'ordine degli elementi
print(numeri)

# %%
nomi.sort()
print(nomi)
nomi.reverse()
print(nomi)

# %% [markdown]
# Attenzione che più varibili possono riferirsi allo stesso oggetto!

# %%
a = [1, 2, 3]
b = a
b[0] = 10
print(a)
print(b)

x = [1, "2", "tre"]
y = x
y.append(False)
print(x)

# %%
c = a.copy()
c[0] = 20
print(a)
print(c)

# %% [markdown]
# #### Array di tipo `tuple`
#
# Una **tupla** è una sequenza ordinata ma non modificabile. Si definisce generalmente racchiudendo gli elementi tra parentesi tonde.

# %%
t = (1, True, "Hello")
print(t)
print(t[0])     
print(t[-1]) 
print(type(t))

# %% [markdown]
# Attenzione: per creare una tupla con un solo elemento è necessaria la virgola

# %%
x = (5)    # int
y = (5,)   # tuple

print(type(x))
print(type(y))

# %% [markdown]
# Una tupla è **immutabile** (immutable): dopo la sua creazione non è possibile sostituire, aggiungere o eliminare elementi.

# %%
t[0] = 4.0
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Le tuple sono utili per rappresentare collezioni di valori che non devono essere modificate, come coordinate, dimensioni o risultati multipli restituiti da una funzione (quest'ultima operazione è detta **unpacking**).

# %%
nome, voto = ("Anna", 28) # tupla come output di una funzione

print(nome)
print(type(nome))
print(voto)

# %% [markdown]
# #### Array di tipo `range`
# Come le tuple, anche gli oggetti di tipo `range` rappresentano sequenze ordinate, indicizzate ma immutabili.
# Un range contiene però solo numeri interi ed è utilizzato soprattutto nei cicli for.

# %%
r = range(7) # 0, 1, 2, 3, 4, 5, 6

print(type(r)) 
print(len(r))   # 7
print(r[0])     # primo valore è 0
print(r[-1])    # il valore 7 è escluso

# %% [markdown]
# Un oggetto range non costruisce esplicitamente in memoria la lista completa dei valori. Per visualizzarli tutti, è possibile convertirlo in una lista

# %%
print(r) 
print(list(r))

# %% [markdown]
# La sintassi generale è:  `range(inizio, fine, passo)`. Di default:
# * l'inizio è 0
# * il passo è 1
#
# L'ultimo valore contenuto nel range è fine-passo

# %%
range(5)        # 0, 1, 2, 3, 4 
range(2, 6)     # 2, 3, 4, 5 
range(2, 10, 2) # 2, 4, 6, 8 
range(5, 0, -1) # 5, 4, 3, 2, 1

# %% [markdown]
# #### Lo slicing per le strutture ordinate
#
# Lo slicing permette di estrarre una parte di una sequenza. La sintassi generale è:
#
# `sequenza[inizio:fine:passo]`
#
# L’elemento nella posizione inizio è incluso, mentre quello nella posizione fine è escluso.

# %%
print(nomi)     # list
print(nomi[1:6])
print(nomi[1:6:2])

print(t)        # tupla
print(t[1:])

print(r)        # range
print(r[1:6])
print(list(r[1:6]))

# %%
print(nomi)
print(nomi[-1])
print(nomi[:4])     # parte da 0
print(nomi[4:])     # fino alla fine
print(nomi[::3])    # indico solo il passo
print(nomi[::-1])

# %% [markdown]
# #### `set`
#
# Un **insieme** è una collezione non ordinata di elementi distinti. Si definisce racchiudendo gli elementi tra parentesi graffe.
#
# ```python
# numeri = {1, 2, 3, 4}
# ```
#
# Gli elementi duplicati vengono eliminati automaticamente:
#
# ```python
# numeri = {1, 2, 2, 3, 3}
#
# print(numeri)  # {1, 2, 3}
# ```
#
# Poiché un insieme non è ordinato, i suoi elementi non possono essere recuperati mediante un indice:
#
# ```python
# numeri[0]
# # TypeError: 'set' object is not subscriptable
# ```
#
# È possibile aggiungere e rimuovere elementi:
#
# ```python
# numeri.add(4)
# numeri.remove(2)
# ```
#
# Gli insiemi supportano le principali operazioni insiemistiche:
#
# ```python
# A = {1, 2, 3}
# B = {3, 4, 5}
#
# print(A | B)  # unione: {1, 2, 3, 4, 5}
# print(A & B)  # intersezione: {3}
# print(A - B)  # differenza: {1, 2}
# print(A ^ B)  # differenza simmetrica: {1, 2, 4, 5}
# ```
#
# Un insieme vuoto deve essere creato con `set()`:
#
# ```python
# insieme_vuoto = set()
# ```
#
# La scrittura `{}` crea invece un dizionario vuoto.

# %% [markdown]
# #### `dict`
#
# Un **dizionario** memorizza associazioni tra **chiavi** e **valori**. Si definisce mediante parentesi graffe, separando ogni chiave dal valore corrispondente con i due punti.
#
# ```python
# studente = {
#     "nome": "Anna",
#     "matricola": 12345,
#     "voto": 28
# }
# ```
#
# A differenza delle sequenze, i valori non vengono recuperati mediante un indice numerico, ma attraverso la chiave associata:
#
# ```python
# print(studente["nome"])  # Anna
# print(studente["voto"])  # 28
# ```
#
# Le chiavi devono essere uniche. Se si assegna nuovamente un valore a una chiave esistente, il valore precedente viene sostituito:
#
# ```python
# studente["voto"] = 30
# ```
#
# È possibile aggiungere una nuova coppia chiave-valore:
#
# ```python
# studente["corso"] = "Analisi numerica"
# ```
#
# e rimuoverla:
#
# ```python
# del studente["matricola"]
# ```
#
# Alcuni metodi utili sono:
#
# ```python
# studente.keys()    # restituisce le chiavi
# studente.values()  # restituisce i valori
# studente.items()   # restituisce le coppie chiave-valore
# ```
#
# Il metodo `get()` permette di cercare una chiave evitando un errore se questa non è presente:
#
# ```python
# print(studente.get("nome"))            # Anna
# print(studente.get("età"))             # None
# print(studente.get("età", "non nota")) # non nota
# ```
#
# Con le parentesi quadre, invece, una chiave inesistente produce un `KeyError`:
#
# ```python
# print(studente["età"])
# # KeyError: 'età'
# ```

# %% [markdown]
# ## (2) Costrutti per il controllo del flusso
#
# Le strutture di controllo permettono di stabilire quali istruzioni devono essere eseguite e in quale ordine. In particolare, le strutture condizionali consentono di eseguire un blocco di codice soltanto quando sono verificate determinate condizioni, mentre i cicli permettono di ripetere una o più istruzioni.

# %% [markdown]
# ### 2.1 Struttura condizionale `if`
#
# La sintassi generale per un `if` è:
#
# ```python
# if <condizione>:
#     <istruzioni>
#
# elif <condizione_alternativa>:
#     <istruzioni_alternative>
#
# else:
#     <istruzioni_finali>
# ```
#
# Le istruzioni del blocco `if` vengono eseguite se la condizione è valutata come True. In caso contrario, vengono controllate le eventuali condizioni `elif`. Il blocco `else` viene eseguito se nessuna delle condizioni precedenti è verificata. L’indentazione identifica le istruzioni appartenenti a ciascun blocco.
#
# I blocchi `elif` e `else` sono opzionali. Possono essere presenti più blocchi `elif`, ma un solo blocco `else`.

# %%
# Define condition
condition = True

if condition:
    print("Condizione vera")
else:
    print("Condizione falsa")

# %%
x = -3

if x > 0:
    print("x è positivo")
elif x < 0:
    print("x è negativo")
else:
    print("x è zero")

# %% [markdown]
# Nelle condizioni, usiamo gli operatori di confronto e/o logici

# %%
# Confronto
print(x == 0)
print(x != 0)
print(x < 0)
print(x <= 0)
print(x > 0)
print(x >= 0)

# Operatori logici: and (&), or (|), not (! or ~)
print(x > 0 and x < 10)
print(x < 0 or x > 10)
print(not x == 0)

# %%
a = 4
b = 2
c = 3

condition_1 = a > b
print(condition_1)
condition_2 = a < c**2
print(condition_2)

if (condition_1) and (not condition_2):
    print("Ok!")
else:
    print("No!")

# %% [markdown]
# ### 2.2 Cicli `for` e `while`
#
# Python mette a disposizione due principali strutture iterative:
#
# - il ciclo `for`, che scorre gli elementi di un oggetto iterabile;
# - il ciclo `while`, che ripete un blocco finché una condizione rimane vera.

# %% [markdown]
# La sintassi generale del ciclo `for` è:
#
# ```python
# for <variabile> in <iterabile>:
#     <istruzioni>
# ```
#
# A ogni iterazione, la variabile assume il valore dell’elemento successivo dell’iterabile.
# Liste, tuple, stringhe, dizionari, insiemi e oggetti range sono esempi di iterabili.

# %%
print(nomi)
for nome in nomi:
    print(nome)

# %%
for carattere in "Python":
    print(carattere)

# %%
for i in range(5):
    print(i)

# %% [markdown]
# Il ciclo `while` ripete un blocco di istruzioni finché una condizione viene valutata come `True`:
#
# ```python
# while <condizione>:
#     <istruzioni>
# ```
# È particolarmente utile quando il numero di iterazioni non è noto in anticipo.

# %%
n = 5

while n > 0:
    print(n)  # print utile per tenere traccia delle iterazioni
    n -= 1

print("Fine!")

# %% [markdown]
# Per evitare cicli infiniti, è buona prassi controllare il `while` e fermarne l'esecuzione dopo un numero (predefinito, `maxit`) di iterazioni, con il comando `break`.

# %%
# Inizializzazioni
cond = True
soglia = 50   # provare 50 e 500
maxit = 15      # massimo numero di iterazioni ammesse
i = 0           # counter

while cond:
    print(f"i = {i}, i² = {i**2}")

    if i**2 > soglia:
        print("Soglia superata.")
        cond = False

    i = i + 1 # Update
    # Controllo sul numero di iterazioni
    if i >= maxit:
        print("Numero massimo di iterazioni raggiunto.")
        break

# %% [markdown]
# ## (3) Organizzazione del codice
#
# Quando un programma cresce, è importante organizzarlo in modo chiaro, modulare e riutilizzabile. In questa sezione vedremo come definire funzioni, utilizzare moduli e pacchetti e gestire correttamente i percorsi di file e cartelle.
#
# Introdurremo inoltre alcuni strumenti utili per valutare il comportamento del codice: la misurazione dei tempi di esecuzione e la lettura dei messaggi di errore, fondamentali per individuare e correggere eventuali problemi.

# %% [markdown]
# ### 3.1 Funzioni
#
# Una funzione è un blocco di codice riutilizzabile che esegue una determinata operazione. Può ricevere uno o più valori in ingresso e restituire uno o più risultati.
#
# La sintassi generale è:
#
# ```python
# def nome_funzione(parametro_1, parametro_2):
#     <istruzioni>
#     return risultato
# ```
# I nomi presenti nella definizione sono detti parametri, mentre i valori forniti quando si richiama la funzione sono detti argomenti. Il `return` rende il risultato disponibile al resto del programma.
#
# Per esempio, definiamo una funzione che somma due numeri:

# %%
def somma(a, b):
    s = a + b

    return s

print(somma(3, 2))

# %% [markdown]
# Una funzione può restituire più valori, separandoli con una virgola. In questo caso, Python raccoglie automaticamente i risultati in una  `tupla`.

# %%
def somma_e_prodotto(a, b): 
    somma = a + b 
    prodotto = a * b 
    return somma, prodotto

risultati = somma_e_prodotto(3, 2) 
print(type(risultati))  # <class 'tuple'>
print(risultati)        # (5, 6) 
print(risultati[0])
print(risultati[1])

# %% [markdown]
# È possibile assegnare direttamente i risultati a variabili distinte mediante l’unpacking:

# %%
s, p = somma_e_prodotto(3, 2)
print(s) # 5 
print(p) # 6

# %% [markdown]
# Si possono definire anche funzioni senza un ritorno di variabili.
# Se una funzione non contiene un’istruzione `return`, oppure esegue `return` senza indicare un valore, restituisce automaticamente `None`.

# %%
def saluta(nome): 
    print(f"Buongiorno {nome}!") 

risultato = saluta("Anna") 
print(risultato)            # None 
print(type(risultato))      # <class 'NoneType'>

# %% [markdown]
# **Nota:**
# in Python le funzioni sono oggetti, quindi possono essere assegnate a variabili e passate come argomenti ad altre funzioni.

# %% [markdown]
# Consideriamo una funzione matematica f(x), la sua derivata f'(x) e la formula
# $$
# x_{\mathrm{new}}=x-\frac{f(x)}{f'(x)},
# $$
# che rappresenta un passo del metodo di Newton per la ricerca degli zeri di (f).
#
# Definiamo quindi una funzione `newton_step` che riceve come argomenti sia le funzioni `f` e `df` che un valore corrente di x:

# %%
def f(x):       # un esempio di funzione derivabile
    return x**2 - 2 

def df(x):      # la derivata analitica deve esser calcolata a mano!
    return 2*x 

def newton_step(f, df, x): 
    return x - f(x) / df(x)

# Main: partendo da x=2, calcoliamo un passo del metodo di Newton
x = 2 
x_new = newton_step(f, df, x) 
print(x_new)

# %% [markdown]
# Nella chiamata non si scrivono le parentesi dopo f e df. Infatti:
#
# * `newton_step(f, df, x)`      passa le funzioni
# * `newton_step(f(x), df(x), x)`  passa i valori ottenuti valutando le funzioni in x

# %% [markdown]
# ### 3.2 Moduli e pacchetti
# Le funzionalità di base di Python possono essere ampliate mediante moduli e pacchetti, che raccolgono funzioni, costanti e altri strumenti già implementati. Nell’uso quotidiano, si adopera spesso la parola pacchetto in senso ampio per indicare un’intera libreria installabile, ma più precisamente:
#
# * un modulo è normalmente un singolo file Python .py contenente funzioni, classi o variabili;
# * un pacchetto è una cartella che organizza più moduli ed eventualmente altri sottopacchetti.
#
# Alcuni moduli, come `math` e `random`, fanno parte della libreria standard e sono disponibili senza installazioni aggiuntive. Per utilizzarli è necessario importarli con il comando `import`, poi si accede agli elementi scrivendo il nome del modulo seguito da un punto:

# %%
# Load in memoria
import math
import random

x = random.random() # Numero casuale nell'intervallo [0, 1)
y= math.exp(x) # Esponenziale di x
print(x,y)

# %% [markdown]
# È possibile assegnare al modulo un nome abbreviato mediante la parola chiave `as`:

# %%
import random as rnd

x = rnd.random()
print(x)

# %% [markdown]
# Si possono anche importare soltanto specifiche funzioni con `from` e `import`. In questo caso, le funzioni possono essere utilizzate senza anteporre il nome del modulo.

# %%
from math import exp, sqrt

print(exp(1))       # non math.exp
print(sqrt(2))

# %% [markdown]
# **Nota**: il modulo `math` opera principalmente su singoli valori numerici. Per applicare funzioni matematiche a vettori, matrici o array si utilizza normalmente la libreria NumPy.

# %%
# Costanti matematiche
x = math.pi       # π
y = math.e        # numero di Eulero
math.inf      # infinito
math.nan      # valore numerico non definito

print(f"pi = {x:0.6f}")
print(f"e = {y:0.6f}")

# Funzioni elementari
math.sqrt(x)     # radice quadrata
math.exp(x)      # esponenziale
math.log(x)      # logaritmo naturale
math.log10(x)    # logaritmo in base 10
math.factorial(n)# fattoriale di intero
math.pow(x, y)   # x elevato a y
x**y             # potenza
print(x**2)

# %%
# Funzioni trigonometriche
math.sin(x)
math.cos(x)
math.tan(x)

# Funzioni di arrotondamento
math.floor(x)  # intero inferiore
math.ceil(x)   # intero superiore
math.trunc(x)  # elimina la parte decimale
math.fabs(x)   # valore assoluto

print(math.floor(x * 100) / 100)

# %% [markdown]
# Molti strumenti per il calcolo scientifico non appartengono alla libreria standard e devono essere installati separatamente come **pacchetti esterni**. Dal terminale, dopo aver attivato l’ambiente (virtual environment) Python corretto, è possibile usare:
# ```
# python -m pip install nome_pacchetto
# ```
#
# Se si utilizza un ambiente Conda, si può invece usare:
#
# ```
# conda install nome_pacchetto
# ```
# Dopo l’installazione, il pacchetto può essere importato normalmente:

# %%
import numpy

# %% [markdown]
# I principali pacchetti utilizzati durante il corso saranno:
#
# - `numpy` che offre gli strumenti di base per lavorare con array e matrici;
# - `scipy` che aggiunge algoritmi scientifici più avanzati;
# - `matplotlib` per l'elaborazione di grafici.

# %% [markdown]
# ### 3.3 Percorsi
#
# Un **percorso** (*path*) è l’indirizzo che identifica la posizione di un file o di una cartella nel file system. Saper costruire correttamente un percorso è necessario, per esempio, per caricare un dataset contenuto in un file `.csv`.
#
# Esistono due tipi principali di percorso:
#
# * un *percorso assoluto* specifica la posizione completa del file: `C:\Users\utente\Desktop\corso\dati\file.csv`
#
# * un *percorso relativo* descrive la posizione del file rispetto alla cartella di lavoro corrente: `dati\file.csv`
#
# La cartella rispetto alla quale vengono interpretati i percorsi relativi è la *cartella di lavoro corrente* (current working directory, cwd). In un Jupyter Notebook la cartella di lavoro è quella da cui è stato avviato il kernel e non coincide necessariamente con la cartella nella quale è salvato il notebook.
#
# È possibile visualizzare la cwd usando il modulo `os` della libreria standard:

# %%
import os
print(os.getcwd())

# %% [markdown]
# Per costruire percorsi è consigliabile utilizzare `pathlib`, che gestisce automaticamente le differenze tra sistemi operativi:

# %%
from pathlib import Path

cartella_corrente = Path.cwd()
percorso_file = cartella_corrente / "dati" / "file.csv"

print(cartella_corrente)
print(percorso_file)

# Controllo se il file esiste:
print(percorso_file.exists())

# %% [markdown]
# Possiamo ottenere la lista dei nomi del file in una determinata cartella con:

# %%
percorso_dati = cartella_corrente / "dati" 
print(os.listdir(percorso_dati))

# %% [markdown]
# ### 3.4 Misurare il tempo macchina
#
# L’efficienza è un aspetto fondamentale degli algoritmi numerici, che spesso operano su grandi quantità di dati. Un primo modo per confrontare algoritmi diversi consiste nel misurarne il *tempo di esecuzione*.
#
# Il tempo dipende dal computer utilizzato e dalle operazioni eseguite contemporaneamente dal sistema; è quindi una misura indicativa, ma utile per confrontare più implementazioni nelle stesse condizioni.
#
# Il modulo `time` della libreria standard fornisce le funzioni `perf_counter()` e `time.time()`, che salvano il tempo istananeo e lo salvano in una variabile.
# Possiamo quindi misurare gli intervalli di tempo così:

# %%
import time

ripetizioni = 20000

# Salvo l'istante temporale di partenza
inizio = time.perf_counter()
start_time = time.time()

for _ in range(ripetizioni):
    somma = sum(range(10000))

# Salvo l'istante temporale di fine
fine = time.perf_counter()
end_time = time.time()

# L'intervallo di tempo è datao dalla differenza dei tempi di inizio-fine
print(f"Tempo di esecuzione: {(fine - inizio):.8f} secondi")
print(end_time - start_time)

tempo_medio = (fine - inizio) / ripetizioni 
print(f"Tempo medio: {tempo_medio:.8f} secondi")

print(inizio)
print(type(inizio))
print(start_time)
print(type(start_time))

# %% [markdown]
# ### 3.5 Errori nel codice
#
# La gestione degli errori è una parte fondamentale della programmazione. Gli errori possono verificarsi per molte ragioni, come un dato di ingresso non valido, una divisione per zero o il tentativo di accedere a un file inesistente. Python fornisce strumenti per intercettare e gestire questi problemi, evitando che il programma si interrompa in modo inatteso e facilitando il **debugging**.
#
# Quando si verifica un errore, Python genera un messaggio chiamato **traceback**, che contiene informazioni sul tipo di errore, sulla riga di codice in cui si è verificato e sulla sequenza di chiamate che ha condotto al problema. Imparare a leggere il traceback è essenziale per individuare e correggere la causa di un errore.

# %%
def divisione(a, b):
    return a / b

# Errore perchè non si può dividere per zero
divisione(10, 0)

# %% [markdown]
# #### Come leggere un traceback
#
# Il traceback può essere interpretato nel modo seguente:
#
# * **`Traceback (most recent call last)`**: introduce la sequenza delle chiamate che hanno condotto all’errore.
# * **`Cell In [...], line 5`**: indica la cella e la riga da cui è stata chiamata la funzione.
# * **`Cell In [...], line 2, in divisione`**: segnala che l’errore si è verificato nella funzione `divisione`, alla riga 2.
# * **`ZeroDivisionError: division by zero`**: specifica il tipo di errore (`ZeroDivisionError`) e la sua causa (`division by zero`).
#
# In generale, per interpretare un traceback conviene partire dall’ultima riga, che contiene il tipo e il messaggio dell’errore, e risalire poi alle righe di codice indicate.
#
# #### Errori frequenti
#
# 1. **`SyntaxError`**: la sintassi del codice non è valida, per esempio per la mancanza di una parentesi o dei due punti.

# %%
if 10 > 5
    print("esempio di Syntax Error")

# %% [markdown]
# 2. **`TypeError`**: un’operazione viene applicata a un oggetto di tipo non appropriato.

# %%
print("10" + 5)

# %% [markdown]
# 3. **`NameError`**: viene utilizzata una variabile o una funzione che non è stata definita.

# %%
print(pippo)

# %% [markdown]
# 4. **`IndexError`**: si tenta di accedere a un indice inesistente di una sequenza.

# %%
lst = [1, 2, 3]
print(lst[5])

# %% [markdown]
# 5. **`ValueError`**: il tipo dell’argomento è corretto, ma il suo valore non è accettabile.

# %%
int("abc")

# %% [markdown]
# 6. **`IndentationError`**: l’indentazione è mancante o incoerente.

# %%
x = 5

if x > 0:
print("x è positivo")

# %% [markdown]
# 7. **`FileNotFoundError`**: il file indicato non esiste oppure il percorso non è corretto.

# %%
file = open(cartella_corrente / "dati" / "file.csv", "r")

# %% [markdown]
# 8. **`ZeroDivisionError`**: si tenta di dividere per zero.

# %%
a = 10
b = 0

risultato = a / b

# %% [markdown]
# ## (4) Esercizi

# %% [markdown]
# ### Esercizio 1.
# Assegna alle variabili `a`, `b` e `c` rispettivamente un intero, un numero decimale e una stringa.
# Stampa valore e tipo di ciascuna variabile.
#
# Converti poi:
# * a in un float;
# * b in un int.

# %% [markdown]
# ### Esercizio 2.
# Dati `a=17` e `b=5`, calcola e stampa:
# * somma e prodotto;
# * divisione, divisione intera e modulo resto;
# * a elevato alla b;
# * coseno di b.

# %% [markdown]
# ### Esercizio 3.
# Definisci le variabili `studente` e `voto`, assegna rispettivamente un nome (Anna) e un intero (28), poi stampa la seguente frase utilizzando una f-stringa:
# *Anna ha ottenuto 28/30*

# %% [markdown]
# ### Esercizio 4.
# Definita la lista `numeri = [2, 5, 8, 11, 14, 17, 20]` estrai:
# * i primi tre elementi;
# * l'ultimo elemento
# * gli elementi dall'8 al 17;
# * gli elementi con indice pari;
# * la lista in ordine inverso.

# %% [markdown]
# ### Esercizio 5.
# Definisci un intero `n` (n>10), poi calcola con un ciclo `for` la la somma dei numeri interi da 1 a n (incluso). Stampa il risultato e aggiungi un controllo per stabilire se la somma è pari o dispari.

# %% [markdown]
# ### Esercizio 6.
# Scrivi una funzione `def media(a, b, c):` che restituisca la media di tre numeri. Richiamala con alcuni valori e stampa il risultato con due cifre decimali.

# %% [markdown]
# ### Esercizio 7.
# Scrivi una funzione che riceva due numeri e restituisca:
# * la loro somma;
# * il loro prodotto;
# * il maggiore dei due.
# Recupera i tre risultati mediante unpacking.

# %% [markdown]
# ### Esercizio 8.
# Prevedi i risultati dei seguenti codici, prima di eseguirli.

# %%
for i in range(1, 8, 2):
    print(i)

# %%
def funzione():
    x = 10

funzione()
print(x)

# %%
a = [1, 2, 3]
b = a
b[0] = 10

print(a)
print(b)
